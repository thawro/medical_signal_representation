# %%
# %load_ext autoreload
# %autoreload 2

from msr.signals.ecg import ECGSignal, create_multichannel_ecg
from msr.data.raw.ptbxl import load_ptbxl_raw_data
import matplotlib.pyplot as plt

# %%
data = load_raw_tensor("val")

sig_data = data[0, :, 1]
multi_sig_data = data[0]

sig = ECGSignal("ecg_II", sig_data.numpy(), fs=100, start_sec=0)
multi_sig = create_multichannel_ecg(multi_sig_data.T.numpy(), fs=100)

sig.set_beats()
sig.set_agg_beat()

multi_sig.set_beats(source_channel="ecg_2")
multi_sig.set_agg_beat()
# Out:
# /home/shate/.cache/pypoetry/virtualenvs/msr-xbuxOujG-py3.8/lib/python3.8/site-packages/neurokit2/epochs/epochs_create.py:205: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for colname, column in epochs[i].select_dtypes(include=["object"]).iteritems():
# /home/shate/.cache/pypoetry/virtualenvs/msr-xbuxOujG-py3.8/lib/python3.8/site-packages/neurokit2/epochs/epochs_create.py:205: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for colname, column in epochs[i].select_dtypes(include=["object"]).iteritems():

# %%
dict(sig.extract_features(return_arr=False))
# Out:
# {'ecg_II_basic_features__mean': 0.004547999999999988,
#  'ecg_II_basic_features__std': 0.3398863099567266,
#  'ecg_II_basic_features__median': 0.081,
#  'ecg_II_basic_features__skewness': -0.3327771344386133,
#  'ecg_II_basic_features__kurtosis': -1.1503023281350755,
#  'ecg_II_agg_beat_features__agg_beat_basic_features__mean': 0.008598255530596207,
#  'ecg_II_agg_beat_features__agg_beat_basic_features__std': 0.07739341344853908,
#  'ecg_II_agg_beat_features__agg_beat_basic_features__median': -0.01977967731757873,
#  'ecg_II_agg_beat_features__agg_beat_basic_features__skewness': 1.5261515201511129,
#  'ecg_II_agg_beat_features__agg_beat_basic_features__kurtosis': 1.968802125114827,
#  'ecg_II_agg_beat_features__agg_beat_crit_points__p_onset_loc': 11,
#  'ecg_II_agg_beat_features__agg_beat_crit_points__p_onset_time': 0.07505024999999999,
#  'ecg_II_agg_beat_features__agg_beat_crit_points__p_onset_val': -0.03025713195576583,
# ...

# %%
dict(multi_sig.extract_features(return_arr=False))
# Out:
# {'ecg_12_basic_features__mean': 0.002064999999999998,
#  'ecg_12_basic_features__std': 0.1866449537892734,
#  'ecg_12_basic_features__median': -0.04,
#  'ecg_12_basic_features__skewness': 1.8222458831191433,
#  'ecg_12_basic_features__kurtosis': 6.199837767396412,
#  'ecg_12_agg_beat_features__agg_beat_basic_features__mean': 0.011933026616180073,
#  'ecg_12_agg_beat_features__agg_beat_basic_features__std': 0.13806876324547052,
#  'ecg_12_agg_beat_features__agg_beat_basic_features__median': -0.03720021058135731,
#  'ecg_12_agg_beat_features__agg_beat_basic_features__skewness': 1.9488347249754172,
#  'ecg_12_agg_beat_features__agg_beat_basic_features__kurtosis': 4.527808990774892,
#  'ecg_12_agg_beat_features__agg_beat_crit_points__p_onset_loc': 11,
#  'ecg_12_agg_beat_features__agg_beat_crit_points__p_onset_time': 0.07505024999999999,
#  'ecg_12_agg_beat_features__agg_beat_crit_points__p_onset_val': -0.05360875589665937,
#  'ecg_12_agg_beat_features__agg_beat_crit_points__p_loc': 18,
# ...
