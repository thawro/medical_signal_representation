# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set(style="whitegrid")

# %% [markdown]
# # **Loading data and creating Signals objects**

# %%
from msr.data.download.sleep_edf import load_sleep_edf_raw_tensors_for_split, FS
from msr.data.measurements import SleepEDFMeasurement

data, targets = load_sleep_edf_raw_tensors_for_split("val")
data, targets = data.numpy(), targets.numpy()
sample = data[111]
eeg_0, eeg_1, eog = sample
measurement = SleepEDFMeasurement(eeg_0, eeg_1, eog, FS)
eeg_sig = measurement['eeg_0']
eog_sig = measurement['eog']

measurement.plot(0, 30)

# %%
feats = eog_sig.extract_features(return_arr=False, plot=True)

# %%
feats
# Out:
# {'basic__entropy': 6.575979635562066,
#  'basic__zero_num_crosses': 171,
#  'basic__zero_pos_cross_std': 76.0556798404048,
#  'basic__zero_neg_cross_std': 68.44923284686442,
#  'basic__mean_num_crosses': 169,
#  'basic__mean_pos_cross_std': 66.87372182854648,
#  'basic__mean_neg_cross_std': 68.6208074322786,
#  'basic__percentile_5': -172.2499633699633,
#  'basic__percentile_25': -70.81269841269837,
#  'basic__percentile_75': 68.49670329670336,
#  'basic__percentile_95': 195.3409523809522,
#  'basic__median': -5.150183150183095,
#  'basic__mean': 2.6223837199837727,
#  'basic__std': 107.36999973001987,
#  'basic__var': 11528.316842024466,
#  'basic__root_mean_square': 85.48483223443223,
#  'basic__kurtosis': -0.3657939550417648,
#  'basic__skew': 0.2804777285327059,
#  'basic__energy': 34605581.21519773,
#  'peaks_troughs__peaks__entropy': 6.0166112956690725,
#  'peaks_troughs__peaks__zero_num_crosses': 53,
#  'peaks_troughs__peaks__zero_pos_cross_std': 115.42408760739676,
#  'peaks_troughs__peaks__zero_neg_cross_std': 124.36539502325373,
#  'peaks_troughs__peaks__mean_num_crosses': 51,
#  'peaks_troughs__peaks__mean_pos_cross_std': 131.95745842252848,
#  'peaks_troughs__peaks__mean_neg_cross_std': 132.69740615400138,
#  'peaks_troughs__peaks__percentile_5': -158.40244200244194,
#  'peaks_troughs__peaks__percentile_25': -65.92673992673987,
#  'peaks_troughs__peaks__percentile_75': 83.75042735042742,
#  'peaks_troughs__peaks__percentile_95': 213.8837606837608,
#  'peaks_troughs__peaks__median': 2.7150183150183707,
#  'peaks_troughs__peaks__mean': 13.318538725946189,
#  'peaks_troughs__peaks__std': 106.87619853420904,
#  'peaks_troughs__peaks__var': 11422.521813123665,
#  'peaks_troughs__peaks__root_mean_square': 85.55570939274644,
#  'peaks_troughs__peaks__kurtosis': -0.37171146507437847,
#  'peaks_troughs__peaks__skew': 0.3259829944267851,
#  'peaks_troughs__peaks__energy': 34764916.144893676,
#  'peaks_troughs__troughs__entropy': 6.0314590213999075,
#  'peaks_troughs__troughs__zero_num_crosses': 60,
#  'peaks_troughs__troughs__zero_pos_cross_std': 112.90142807491644,
#  'peaks_troughs__troughs__zero_neg_cross_std': 104.15812775148375,
#  'peaks_troughs__troughs__mean_num_crosses': 56,
#  'peaks_troughs__troughs__mean_pos_cross_std': 114.2747153241445,
#  'peaks_troughs__troughs__mean_neg_cross_std': 108.99765291139092,
#  'peaks_troughs__troughs__percentile_5': -183.18974358974356,
#  'peaks_troughs__troughs__percentile_25': -78.79706959706955,
#  'peaks_troughs__troughs__percentile_75': 57.533089133089184,
#  'peaks_troughs__troughs__percentile_95': 186.2363858363859,
#  'peaks_troughs__troughs__median': -12.538705738705684,
#  'peaks_troughs__troughs__mean': -6.385937748900658,
#  'peaks_troughs__troughs__std': 106.73118476020564,
#  'peaks_troughs__troughs__var': 11391.545800317152,
#  'peaks_troughs__troughs__root_mean_square': 84.99277902240864,
#  'peaks_troughs__troughs__kurtosis': -0.3343921792789275,
#  'peaks_troughs__troughs__skew': 0.27531164109405026,
#  'peaks_troughs__troughs__energy': 34262681.02574586,
#  'peaks_troughs__amplitudes__entropy': 6.096168735337034,
#  'peaks_troughs__amplitudes__zero_num_crosses': 0,
#  'peaks_troughs__amplitudes__zero_pos_cross_std': -1,
#  'peaks_troughs__amplitudes__zero_neg_cross_std': -1,
#  'peaks_troughs__amplitudes__mean_num_crosses': 441,
#  'peaks_troughs__amplitudes__mean_pos_cross_std': 16.465612866843223,
#  'peaks_troughs__amplitudes__mean_neg_cross_std': 16.338042484686007,
#  'peaks_troughs__amplitudes__percentile_5': 0.9533577533577517,
#  'peaks_troughs__amplitudes__percentile_25': 3.813431013431014,
#  'peaks_troughs__amplitudes__percentile_75': 26.69401709401709,
#  'peaks_troughs__amplitudes__percentile_95': 63.874969474969475,
#  'peaks_troughs__amplitudes__median': 10.486935286935287,
#  'peaks_troughs__amplitudes__mean': 19.704476474846846,
#  'peaks_troughs__amplitudes__std': 26.491599561687835,
#  'peaks_troughs__amplitudes__var': 701.8048473368191,
#  'peaks_troughs__amplitudes__root_mean_square': 19.704476474846846,
#  'peaks_troughs__amplitudes__kurtosis': 19.29345542004087,
#  'peaks_troughs__amplitudes__skew': 3.6116912890309623,
#  'peaks_troughs__amplitudes__energy': 3266943.507732382,
#  'DWT__detail_1_freq_(33.335, 66.67)__entropy': 7.315883504509786,
#  'DWT__detail_1_freq_(33.335, 66.67)__zero_num_crosses': 797,
#  'DWT__detail_1_freq_(33.335, 66.67)__zero_pos_cross_std': 1.8920181909879772,
#  'DWT__detail_1_freq_(33.335, 66.67)__zero_neg_cross_std': 1.983303719975194,
#  'DWT__detail_1_freq_(33.335, 66.67)__mean_num_crosses': 783,
#  'DWT__detail_1_freq_(33.335, 66.67)__mean_pos_cross_std': 2.016250591833324,
#  'DWT__detail_1_freq_(33.335, 66.67)__mean_neg_cross_std': 2.1026031891301247,
#  'DWT__detail_1_freq_(33.335, 66.67)__percentile_5': -18.98477556713606,
#  'DWT__detail_1_freq_(33.335, 66.67)__percentile_25': -3.351508907135051,
#  'DWT__detail_1_freq_(33.335, 66.67)__percentile_75': 3.6614857145778754,
#  'DWT__detail_1_freq_(33.335, 66.67)__percentile_95': 20.336437016406588,
#  'DWT__detail_1_freq_(33.335, 66.67)__median': 0.021402706482417384,
#  'DWT__detail_1_freq_(33.335, 66.67)__mean': 0.3315043952612375,
#  'DWT__detail_1_freq_(33.335, 66.67)__std': 13.14688145049303,
#  'DWT__detail_1_freq_(33.335, 66.67)__var': 172.84049187331772,
#  'DWT__detail_1_freq_(33.335, 66.67)__root_mean_square': 7.647612531337847,
#  'DWT__detail_1_freq_(33.335, 66.67)__kurtosis': 8.89399716430179,
#  'DWT__detail_1_freq_(33.335, 66.67)__skew': 0.4218645906758349,
#  'DWT__detail_1_freq_(33.335, 66.67)__energy': 260117.38210424254,
#  'DWT__detail_2_freq_(16.665, 33.33)__entropy': 6.628041376179532,
#  'DWT__detail_2_freq_(16.665, 33.33)__zero_num_crosses': 427,
#  'DWT__detail_2_freq_(16.665, 33.33)__zero_pos_cross_std': 1.6826254401368477,
#  'DWT__detail_2_freq_(16.665, 33.33)__zero_neg_cross_std': 1.7169033778786633,
#  'DWT__detail_2_freq_(16.665, 33.33)__mean_num_crosses': 427,
#  'DWT__detail_2_freq_(16.665, 33.33)__mean_pos_cross_std': 1.7294082181316417,
#  'DWT__detail_2_freq_(16.665, 33.33)__mean_neg_cross_std': 1.725125820270399,
#  'DWT__detail_2_freq_(16.665, 33.33)__percentile_5': -19.294503941383425,
#  'DWT__detail_2_freq_(16.665, 33.33)__percentile_25': -4.3183902938743834,
#  'DWT__detail_2_freq_(16.665, 33.33)__percentile_75': 4.233686821013148,
#  'DWT__detail_2_freq_(16.665, 33.33)__percentile_95': 18.515489998664677,
#  'DWT__detail_2_freq_(16.665, 33.33)__median': -0.05784913245424937,
#  'DWT__detail_2_freq_(16.665, 33.33)__mean': -0.16474252241937268,
#  'DWT__detail_2_freq_(16.665, 33.33)__std': 11.973833694151368,
#  'DWT__detail_2_freq_(16.665, 33.33)__var': 143.37269333519458,
#  'DWT__detail_2_freq_(16.665, 33.33)__root_mean_square': 7.586782962656988,
#  'DWT__detail_2_freq_(16.665, 33.33)__kurtosis': 6.906381575663284,
#  'DWT__detail_2_freq_(16.665, 33.33)__skew': 0.3656876290986665,
#  'DWT__detail_2_freq_(16.665, 33.33)__energy': 108410.2740760191,
#  'DWT__detail_3_freq_(8.335, 16.67)__entropy': 5.945420608606579,
#  'DWT__detail_3_freq_(8.335, 16.67)__zero_num_crosses': 210,
#  'DWT__detail_3_freq_(8.335, 16.67)__zero_pos_cross_std': 1.805542912007519,
#  'DWT__detail_3_freq_(8.335, 16.67)__zero_neg_cross_std': 1.661848929327009,
#  'DWT__detail_3_freq_(8.335, 16.67)__mean_num_crosses': 212,
#  'DWT__detail_3_freq_(8.335, 16.67)__mean_pos_cross_std': 1.5787707264839697,
#  'DWT__detail_3_freq_(8.335, 16.67)__mean_neg_cross_std': 1.542915930684818,
#  'DWT__detail_3_freq_(8.335, 16.67)__percentile_5': -28.648612859792628,
#  'DWT__detail_3_freq_(8.335, 16.67)__percentile_25': -7.643060232506461,
#  'DWT__detail_3_freq_(8.335, 16.67)__percentile_75': 5.32459969732254,
#  'DWT__detail_3_freq_(8.335, 16.67)__percentile_95': 24.38028947095187,
#  'DWT__detail_3_freq_(8.335, 16.67)__median': -0.4244139383334118,
#  'DWT__detail_3_freq_(8.335, 16.67)__mean': -1.0093277372758116,
#  'DWT__detail_3_freq_(8.335, 16.67)__std': 16.036707416010643,
#  'DWT__detail_3_freq_(8.335, 16.67)__var': 257.1759847467307,
#  'DWT__detail_3_freq_(8.335, 16.67)__root_mean_square': 10.74676084782149,
#  'DWT__detail_3_freq_(8.335, 16.67)__kurtosis': 3.2596673610416103,
#  'DWT__detail_3_freq_(8.335, 16.67)__skew': 0.025572183253637384,
#  'DWT__detail_3_freq_(8.335, 16.67)__energy': 98630.38580108267,
#  'DWT__detail_4_freq_(4.165, 8.33)__entropy': 5.272999558563746,
#  'DWT__detail_4_freq_(4.165, 8.33)__zero_num_crosses': 127,
#  'DWT__detail_4_freq_(4.165, 8.33)__zero_pos_cross_std': 1.0700005348788377,
#  'DWT__detail_4_freq_(4.165, 8.33)__zero_neg_cross_std': 1.0763262544866468,
#  'DWT__detail_4_freq_(4.165, 8.33)__mean_num_crosses': 127,
#  'DWT__detail_4_freq_(4.165, 8.33)__mean_pos_cross_std': 1.0849696812156218,
#  'DWT__detail_4_freq_(4.165, 8.33)__mean_neg_cross_std': 1.098339294730552,
#  'DWT__detail_4_freq_(4.165, 8.33)__percentile_5': -49.51004185590235,
#  'DWT__detail_4_freq_(4.165, 8.33)__percentile_25': -13.522801441100661,
#  'DWT__detail_4_freq_(4.165, 8.33)__percentile_75': 12.987519777807849,
#  'DWT__detail_4_freq_(4.165, 8.33)__percentile_95': 57.907181784210366,
#  'DWT__detail_4_freq_(4.165, 8.33)__median': -0.006165902026428305,
#  'DWT__detail_4_freq_(4.165, 8.33)__mean': 1.6513773559319247,
#  'DWT__detail_4_freq_(4.165, 8.33)__std': 34.552588717044806,
#  'DWT__detail_4_freq_(4.165, 8.33)__var': 1193.8813870492522,
#  'DWT__detail_4_freq_(4.165, 8.33)__root_mean_square': 22.208981406711544,
#  'DWT__detail_4_freq_(4.165, 8.33)__kurtosis': 9.541655572260307,
#  'DWT__detail_4_freq_(4.165, 8.33)__skew': 1.304661124561061,
#  'DWT__detail_4_freq_(4.165, 8.33)__energy': 233338.64467308254,
#  'DWT__detail_5_freq_(2.085, 4.17)__entropy': 4.6249728132842725,
#  'DWT__detail_5_freq_(2.085, 4.17)__zero_num_crosses': 63,
#  'DWT__detail_5_freq_(2.085, 4.17)__zero_pos_cross_std': 0.8224225021923846,
#  'DWT__detail_5_freq_(2.085, 4.17)__zero_neg_cross_std': 0.8749603165604459,
#  'DWT__detail_5_freq_(2.085, 4.17)__mean_num_crosses': 63,
#  'DWT__detail_5_freq_(2.085, 4.17)__mean_pos_cross_std': 0.8224225021923846,
#  'DWT__detail_5_freq_(2.085, 4.17)__mean_neg_cross_std': 0.835995746932297,
#  'DWT__detail_5_freq_(2.085, 4.17)__percentile_5': -172.74239206406162,
#  'DWT__detail_5_freq_(2.085, 4.17)__percentile_25': -50.16284609484467,
#  'DWT__detail_5_freq_(2.085, 4.17)__percentile_75': 44.315078493118904,
#  'DWT__detail_5_freq_(2.085, 4.17)__percentile_95': 129.49032281303198,
#  'DWT__detail_5_freq_(2.085, 4.17)__median': 5.514682699591014,
#  'DWT__detail_5_freq_(2.085, 4.17)__mean': -3.275296580063516,
#  'DWT__detail_5_freq_(2.085, 4.17)__std': 90.99193541091842,
#  'DWT__detail_5_freq_(2.085, 4.17)__var': 8279.532309824748,
#  'DWT__detail_5_freq_(2.085, 4.17)__root_mean_square': 65.71950906793779,
#  'DWT__detail_5_freq_(2.085, 4.17)__kurtosis': 2.026141619119932,
#  'DWT__detail_5_freq_(2.085, 4.17)__skew': -0.5934726035159072,
#  'DWT__detail_5_freq_(2.085, 4.17)__energy': 845606.5075062369,
#  'DWT__detail_6_freq_(1.04, 2.08)__entropy': 4.007333185232471,
#  'DWT__detail_6_freq_(1.04, 2.08)__zero_num_crosses': 30,
#  'DWT__detail_6_freq_(1.04, 2.08)__zero_pos_cross_std': 0.6102859818083951,
#  'DWT__detail_6_freq_(1.04, 2.08)__zero_neg_cross_std': 0.8206518066482897,
#  'DWT__detail_6_freq_(1.04, 2.08)__mean_num_crosses': 33,
#  'DWT__detail_6_freq_(1.04, 2.08)__mean_pos_cross_std': 0.8692269873603532,
#  'DWT__detail_6_freq_(1.04, 2.08)__mean_neg_cross_std': 0.6614378277661477,
#  'DWT__detail_6_freq_(1.04, 2.08)__percentile_5': -385.3371446485914,
#  'DWT__detail_6_freq_(1.04, 2.08)__percentile_25': -140.42355470816398,
#  'DWT__detail_6_freq_(1.04, 2.08)__percentile_75': 118.76992766568227,
#  'DWT__detail_6_freq_(1.04, 2.08)__percentile_95': 311.55371900287713,
#  'DWT__detail_6_freq_(1.04, 2.08)__median': -13.330438561241236,
#  'DWT__detail_6_freq_(1.04, 2.08)__mean': -14.380340493467312,
#  'DWT__detail_6_freq_(1.04, 2.08)__std': 209.16036863448215,
#  'DWT__detail_6_freq_(1.04, 2.08)__var': 43748.059807312464,
#  'DWT__detail_6_freq_(1.04, 2.08)__root_mean_square': 159.57213414109924,
#  'DWT__detail_6_freq_(1.04, 2.08)__kurtosis': 0.22175741825464002,
#  'DWT__detail_6_freq_(1.04, 2.08)__skew': -0.06296087253982864,
#  'DWT__detail_6_freq_(1.04, 2.08)__energy': 2417516.9700011276,
#  'DWT__detail_7_freq_(0.52, 1.04)__entropy': 3.4657359027997265,
#  'DWT__detail_7_freq_(0.52, 1.04)__zero_num_crosses': 23,
#  'DWT__detail_7_freq_(0.52, 1.04)__zero_pos_cross_std': 0.48989794855663565,
#  'DWT__detail_7_freq_(0.52, 1.04)__zero_neg_cross_std': 0.9791208740244554,
#  'DWT__detail_7_freq_(0.52, 1.04)__mean_num_crosses': 22,
#  'DWT__detail_7_freq_(0.52, 1.04)__mean_pos_cross_std': 0.48989794855663565,
#  'DWT__detail_7_freq_(0.52, 1.04)__mean_neg_cross_std': 0.66332495807108,
#  'DWT__detail_7_freq_(0.52, 1.04)__percentile_5': -762.3663441012116,
#  'DWT__detail_7_freq_(0.52, 1.04)__percentile_25': -377.83054064444457,
#  'DWT__detail_7_freq_(0.52, 1.04)__percentile_75': 390.67480942364466,
#  'DWT__detail_7_freq_(0.52, 1.04)__percentile_95': 839.9964336897137,
#  'DWT__detail_7_freq_(0.52, 1.04)__median': 59.022499073917224,
#  'DWT__detail_7_freq_(0.52, 1.04)__mean': -13.51523046350979,
#  'DWT__detail_7_freq_(0.52, 1.04)__std': 520.2376711988092,
#  'DWT__detail_7_freq_(0.52, 1.04)__var': 270647.23453436024,
#  'DWT__detail_7_freq_(0.52, 1.04)__root_mean_square': 407.4479884842914,
#  'DWT__detail_7_freq_(0.52, 1.04)__kurtosis': -0.16232901386340792,
#  'DWT__detail_7_freq_(0.52, 1.04)__skew': -0.2760760450605502,
#  'DWT__detail_7_freq_(0.52, 1.04)__energy': 8666556.671642944,
#  'DWT__detail_8_freq_(0.26, 0.52)__entropy': 2.9957322735539904,
#  'DWT__detail_8_freq_(0.26, 0.52)__zero_num_crosses': 10,
#  'DWT__detail_8_freq_(0.26, 0.52)__zero_pos_cross_std': 1.920286436967152,
#  'DWT__detail_8_freq_(0.26, 0.52)__zero_neg_cross_std': 1.0897247358851685,
#  'DWT__detail_8_freq_(0.26, 0.52)__mean_num_crosses': 10,
#  'DWT__detail_8_freq_(0.26, 0.52)__mean_pos_cross_std': 1.0897247358851685,
#  'DWT__detail_8_freq_(0.26, 0.52)__mean_neg_cross_std': 1.5,
#  'DWT__detail_8_freq_(0.26, 0.52)__percentile_5': -1084.523212339429,
#  'DWT__detail_8_freq_(0.26, 0.52)__percentile_25': -250.19257054585017,
#  'DWT__detail_8_freq_(0.26, 0.52)__percentile_75': 384.19683803927234,
#  'DWT__detail_8_freq_(0.26, 0.52)__percentile_95': 2021.5437037351878,
#  'DWT__detail_8_freq_(0.26, 0.52)__median': 2.916405725298813,
#  'DWT__detail_8_freq_(0.26, 0.52)__mean': 112.15225899320706,
#  'DWT__detail_8_freq_(0.26, 0.52)__std': 883.2689818489753,
#  'DWT__detail_8_freq_(0.26, 0.52)__var': 780164.0942965255,
#  'DWT__detail_8_freq_(0.26, 0.52)__root_mean_square': 590.8104310030456,
#  'DWT__detail_8_freq_(0.26, 0.52)__kurtosis': 1.1114403415992093,
#  'DWT__detail_8_freq_(0.26, 0.52)__skew': 1.023090710518497,
#  'DWT__detail_8_freq_(0.26, 0.52)__energy': 15854844.469876092,
#  'DWT__approx_8_freq_(0, 0.26)__entropy': 2.9957322735539904,
#  'DWT__approx_8_freq_(0, 0.26)__zero_num_crosses': 11,
#  'DWT__approx_8_freq_(0, 0.26)__zero_pos_cross_std': 0.4330127018922193,
#  'DWT__approx_8_freq_(0, 0.26)__zero_neg_cross_std': 0.39999999999999997,
#  'DWT__approx_8_freq_(0, 0.26)__mean_num_crosses': 11,
#  'DWT__approx_8_freq_(0, 0.26)__mean_pos_cross_std': 0.4330127018922193,
#  'DWT__approx_8_freq_(0, 0.26)__mean_neg_cross_std': 0.39999999999999997,
#  'DWT__approx_8_freq_(0, 0.26)__percentile_5': -1396.2392090745984,
#  'DWT__approx_8_freq_(0, 0.26)__percentile_25': -179.9792731691545,
#  'DWT__approx_8_freq_(0, 0.26)__percentile_75': 712.3326268045562,
#  'DWT__approx_8_freq_(0, 0.26)__percentile_95': 861.2292126866886,
#  'DWT__approx_8_freq_(0, 0.26)__median': 398.01187561933807,
#  'DWT__approx_8_freq_(0, 0.26)__mean': 199.6109767026196,
#  'DWT__approx_8_freq_(0, 0.26)__std': 814.1013206557386,
#  'DWT__approx_8_freq_(0, 0.26)__var': 662760.9602934178,
#  'DWT__approx_8_freq_(0, 0.26)__root_mean_square': 716.7143136242356,
#  'DWT__approx_8_freq_(0, 0.26)__kurtosis': 0.5969421040654672,
#  'DWT__approx_8_freq_(0, 0.26)__skew': -1.0638968595268126,
#  'DWT__approx_8_freq_(0, 0.26)__energy': 14052110.046271833,
#  'DWT__wavelet_entropy': 1.1249567063179866}
