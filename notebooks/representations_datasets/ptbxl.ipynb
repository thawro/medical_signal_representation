# %%
# %load_ext autoreload
# %autoreload 2

from msr.training.data.datasets import PtbXLDataset
from msr.training.data.datamodules import PtbXLDataModule
from msr.data.download.ptbxl import FS

TARGET = "diagnostic_class"
BASE_PARAMS = dict(fs=FS, target=TARGET)

# %% [markdown]
# ---
# # **Whole signal**

# %% [markdown]
# **`whole_signal_waveforms`**

# %%
dm = PtbXLDataModule("whole_signal_waveforms", **BASE_PARAMS)
dm.setup(); dm.plot_targets(); print(dm.describe(ds_fields=['data_shape', 'classes_counts'], dm_fields=['info']))
# Out:
# PtbXLDataModule (whole_signal_waveforms)
#   info       = {0: 'CD', 1: 'HYP', 2: 'MI', 3: 'NORM', 4: 'STTC'}
#
#   Train PtbXLDataset:
#     data_shape            = torch.Size([12978, 1000, 12])
#     classes_counts        = {'NORM': 7254, 'MI': 2048, 'STTC': 1907, 'CD': 1353, 'HYP': 416}
#
#   Val PtbXLDataset:
#     data_shape            = torch.Size([1642, 1000, 12])
#     classes_counts        = {'NORM': 916, 'STTC': 256, 'MI': 234, 'CD': 172, 'HYP': 64}
#
#   Test PtbXLDataset:
#     data_shape            = torch.Size([1652, 1000, 12])
#     classes_counts        = {'NORM': 913, 'MI': 256, 'STTC': 243, 'CD': 184, 'HYP': 56}

# %% [markdown]
# **`whole_signal_features`**

# %%
dm = PtbXLDataModule("whole_signal_features", **BASE_PARAMS)
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# PtbXLDataModule (whole_signal_features)
#
#   Train PtbXLDataset:
#     data_shape            = torch.Size([12978, 3636])
#
#   Val PtbXLDataset:
#     data_shape            = torch.Size([1642, 3636])
#
#   Test PtbXLDataset:
#     data_shape            = torch.Size([1652, 3636])

# %% [markdown]
# ---
# # **Windows**

# %% [markdown]
# **`windows_waveforms`**

# %%
dm = PtbXLDataModule("windows_waveforms", **BASE_PARAMS)
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [4], line 2
#       1 dm = PtbXLDataModule("windows_waveforms", **BASE_PARAMS)
# ----> 2 dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/training/data/datamodules.py:52, in BaseDataModule.setup(self, stage)
#      50 def setup(self, stage=None):
#      51     if stage == "fit" or stage is None:
# ---> 52         self.train = self.DatasetFactory(
#      53             split="train", representation_type=self.representation_type, transform=self.train_transform
#      54         )
#      55         self.val = self.DatasetFactory(
#      56             split="val", representation_type=self.representation_type, transform=self.inference_transform
#      57         )
#      58         self.datasets.extend([self.train, self.val])
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/training/data/datasets.py:148, in PtbXLDataset.__init__(self, split, representation_type, fs, target, transform)
#     146 self.fs = fs
#     147 self.target = target
# --> 148 super().__init__(split, representation_type, transform)
#     149 self.target_name = "Diagnostic statement"
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/training/data/datasets.py:94, in ClassificationDataset.__init__(self, split, representation_type, transform)
#      93 def __init__(self, split: Literal["train", "val", "test"], representation_type: str, transform: Callable = None):
# ---> 94     super().__init__(split, representation_type, transform)
#      95     self.classes = np.array([self.info[target.item()] for target in self.targets])
#      96     self.classes_counts = {k: 0 for k in self.info.values()}
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/training/data/datasets.py:30, in BaseDataset.__init__(self, split, representation_type, transform)
#      28 self.representation_type = representation_type
#      29 self.transform = transform
# ---> 30 dataset = self._dataset_loader(split=split, representation_type=representation_type)
#      31 self.data = dataset["data"].float()
#      32 self.data = torch.nan_to_num(self.data)  # TODO
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/data/dataset_providers.py:136, in DatasetProvider.load_split(self, split, representation_type)
#     134 def load_split(self, split, representation_type):
#     135     representation_path = self.representations_path / representation_type
# --> 136     data = torch.load(representation_path / f"{split}.pt")
#     137     targets = torch.load(self.targets_path / f"{split}.pt")
#     138     try:
#
# File ~/.cache/pypoetry/virtualenvs/msr-xbuxOujG-py3.8/lib/python3.8/site-packages/torch/serialization.py:771, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     768 if 'encoding' not in pickle_load_args.keys():
#     769     pickle_load_args['encoding'] = 'utf-8'
# --> 771 with _open_file_like(f, 'rb') as opened_file:
#     772     if _is_zipfile(opened_file):
#     773         # The zipfile reader is going to advance the current file position.
#     774         # If we want to actually tail call to torch.jit.load, we need to
#     775         # reset back to the original position.
#     776         orig_position = opened_file.tell()
#
# File ~/.cache/pypoetry/virtualenvs/msr-xbuxOujG-py3.8/lib/python3.8/site-packages/torch/serialization.py:270, in _open_file_like(name_or_buffer, mode)
#     268 def _open_file_like(name_or_buffer, mode):
#     269     if _is_path(name_or_buffer):
# --> 270         return _open_file(name_or_buffer, mode)
#     271     else:
#     272         if 'w' in mode:
#
# File ~/.cache/pypoetry/virtualenvs/msr-xbuxOujG-py3.8/lib/python3.8/site-packages/torch/serialization.py:251, in _open_file.__init__(self, name, mode)
#     250 def __init__(self, name, mode):
# --> 251     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/shate/Desktop/praca_magisterska/medical_signal_representation/data/ptbxl/representations_100/windows_waveforms/train.pt'

# %% [markdown]
# **`windows_features`**

# %%
dm = PtbXLDataModule("windows_features", **BASE_PARAMS)
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# PtbXLDataModule (windows_features)
#
#   Train PtbXLDataset:
#     data_shape            = torch.Size([12978, 3, 696])
#
#   Val PtbXLDataset:
#     data_shape            = torch.Size([1642, 3, 696])
#
#   Test PtbXLDataset:
#     data_shape            = torch.Size([1652, 3, 696])

# %% [markdown]
# ---
# # **Beats**

# %% [markdown]
# **`beats_waveforms`**

# %%
dm = PtbXLDataModule("beats_waveforms", **BASE_PARAMS)
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# PtbXLDataModule (beats_waveforms)
#
#   Train PtbXLDataset:
#     data_shape            = torch.Size([12978, 7, 100, 12])
#
#   Val PtbXLDataset:
#     data_shape            = torch.Size([1642, 7, 100, 12])
#
#   Test PtbXLDataset:
#     data_shape            = torch.Size([1652, 7, 100, 12])

# %% [markdown]
# **`beats_features`**

# %%
dm = PtbXLDataModule("beats_features", **BASE_PARAMS)
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# PtbXLDataModule (beats_features)
#
#   Train PtbXLDataset:
#     data_shape            = torch.Size([12978, 7, 600])
#
#   Val PtbXLDataset:
#     data_shape            = torch.Size([1642, 7, 600])
#
#   Test PtbXLDataset:
#     data_shape            = torch.Size([1652, 7, 600])

# %% [markdown]
# ---
# # **Aggregated beat**

# %% [markdown]
# **`agg_beat_waveforms`**

# %%
dm = PtbXLDataModule("agg_beat_waveforms", **BASE_PARAMS)
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# PtbXLDataModule (agg_beat_waveforms)
#
#   Train PtbXLDataset:
#     data_shape            = torch.Size([12978, 100, 12])
#
#   Val PtbXLDataset:
#     data_shape            = torch.Size([1642, 100, 12])
#
#   Test PtbXLDataset:
#     data_shape            = torch.Size([1652, 100, 12])

# %% [markdown]
# **`agg_beat_features`**

# %%
dm = PtbXLDataModule("agg_beat_features", **BASE_PARAMS)
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# PtbXLDataModule (agg_beat_features)
#
#   Train PtbXLDataset:
#     data_shape            = torch.Size([12978, 936])
#
#   Val PtbXLDataset:
#     data_shape            = torch.Size([1642, 936])
#
#   Test PtbXLDataset:
#     data_shape            = torch.Size([1652, 936])

# %% [markdown]
# ---
