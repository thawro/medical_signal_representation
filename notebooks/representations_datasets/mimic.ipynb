# %%
# %load_ext autoreload
# %autoreload 2

from msr.training.data.datasets import MimicDataset
from msr.training.data.datamodules import MimicDataModule

TARGET = "sbp_dbp_avg"

# %% [markdown]
# ---
# # **Whole signal**

# %% [markdown]
# **`whole_signal_waveforms`**

# %%
dm = MimicDataModule("whole_signal_waveforms", target=TARGET)
dm.setup(); dm.plot_targets(); print(dm.describe(ds_fields=['data_shape'], dm_fields=['info']))
# Out:
# No info file for that split
# No info file for that split
# No info file for that split
# MimicDataModule (whole_signal_waveforms)
#   info       = {}
#
#   Train MimicDataset:
#     data_shape            = torch.Size([14559, 7500, 2])
#
#   Val MimicDataset:
#     data_shape            = torch.Size([3130, 7500, 2])
#
#   Test MimicDataset:
#     data_shape            = torch.Size([3153, 7500, 2])

# %% [markdown]
# **`whole_signal_features`**

# %%
dm = MimicDataModule("whole_signal_features")
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# No info file for that split
# No info file for that split
# No info file for that split
# MimicDataModule (whole_signal_features)
#
#   Train MimicDataset:
#     data_shape            = torch.Size([14559, 692])
#
#   Val MimicDataset:
#     data_shape            = torch.Size([3130, 692])
#
#   Test MimicDataset:
#     data_shape            = torch.Size([3153, 692])

# %% [markdown]
# ---
# # **Windows**

# %% [markdown]
# **`windows_waveforms`**

# %%
dm = MimicDataModule("windows_waveforms")
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [5], line 2
#       1 dm = MimicDataModule("windows_waveforms")
# ----> 2 dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/training/data/datamodules.py:52, in BaseDataModule.setup(self, stage)
#      50 def setup(self, stage=None):
#      51     if stage == "fit" or stage is None:
# ---> 52         self.train = self.DatasetFactory(
#      53             split="train", representation_type=self.representation_type, transform=self.train_transform
#      54         )
#      55         self.val = self.DatasetFactory(
#      56             split="val", representation_type=self.representation_type, transform=self.inference_transform
#      57         )
#      58         self.datasets.extend([self.train, self.val])
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/training/data/datasets.py:171, in MimicDataset.__init__(self, split, representation_type, target, bp_targets, transform)
#     168 self.target = target
#     170 self.bp_targets = bp_targets
# --> 171 super().__init__(split, representation_type, transform)
#     172 self.target_name = "Blood pressure"
#     173 bp_targets_idxs = {"sbp": 0, "dbp": 1}
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/training/data/datasets.py:121, in RegressionDataset.__init__(self, split, representation_type, transform)
#     120 def __init__(self, split: Literal["train", "val", "test"], representation_type: str, transform: Callable = None):
# --> 121     super().__init__(split, representation_type, transform)
#     122     self.targets_df = None
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/training/data/datasets.py:30, in BaseDataset.__init__(self, split, representation_type, transform)
#      28 self.representation_type = representation_type
#      29 self.transform = transform
# ---> 30 dataset = self._dataset_loader(split=split, representation_type=representation_type)
#      31 self.data = dataset["data"].float()
#      32 self.data = torch.nan_to_num(self.data)  # TODO
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/data/dataset_providers.py:136, in DatasetProvider.load_split(self, split, representation_type)
#     134 def load_split(self, split, representation_type):
#     135     representation_path = self.representations_path / representation_type
# --> 136     data = torch.load(representation_path / f"{split}.pt")
#     137     targets = torch.load(self.targets_path / f"{split}.pt")
#     138     try:
#
# File ~/.cache/pypoetry/virtualenvs/msr-xbuxOujG-py3.8/lib/python3.8/site-packages/torch/serialization.py:771, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     768 if 'encoding' not in pickle_load_args.keys():
#     769     pickle_load_args['encoding'] = 'utf-8'
# --> 771 with _open_file_like(f, 'rb') as opened_file:
#     772     if _is_zipfile(opened_file):
#     773         # The zipfile reader is going to advance the current file position.
#     774         # If we want to actually tail call to torch.jit.load, we need to
#     775         # reset back to the original position.
#     776         orig_position = opened_file.tell()
#
# File ~/.cache/pypoetry/virtualenvs/msr-xbuxOujG-py3.8/lib/python3.8/site-packages/torch/serialization.py:270, in _open_file_like(name_or_buffer, mode)
#     268 def _open_file_like(name_or_buffer, mode):
#     269     if _is_path(name_or_buffer):
# --> 270         return _open_file(name_or_buffer, mode)
#     271     else:
#     272         if 'w' in mode:
#
# File ~/.cache/pypoetry/virtualenvs/msr-xbuxOujG-py3.8/lib/python3.8/site-packages/torch/serialization.py:251, in _open_file.__init__(self, name, mode)
#     250 def __init__(self, name, mode):
# --> 251     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/shate/Desktop/praca_magisterska/medical_signal_representation/data/mimic/representations/windows_waveforms/train.pt'

# %% [markdown]
# **`windows_features`**

# %%
dm = MimicDataModule("windows_features")
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# No info file for that split
# No info file for that split
# No info file for that split
# MimicDataModule (windows_features)
#
#   Train MimicDataset:
#     data_shape            = torch.Size([14559, 3, 81])
#
#   Val MimicDataset:
#     data_shape            = torch.Size([3130, 3, 81])
#
#   Test MimicDataset:
#     data_shape            = torch.Size([3153, 3, 81])

# %% [markdown]
# ---
# # **Beats**

# %% [markdown]
# **`beats_waveforms`**

# %%
dm = MimicDataModule("beats_waveforms")
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [5], line 2
#       1 dm = MimicDataModule("beats_waveforms")
# ----> 2 dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/training/data/datamodules.py:52, in BaseDataModule.setup(self, stage)
#      50 def setup(self, stage=None):
#      51     if stage == "fit" or stage is None:
# ---> 52         self.train = self.DatasetFactory(
#      53             split="train", representation_type=self.representation_type, transform=self.train_transform
#      54         )
#      55         self.val = self.DatasetFactory(
#      56             split="val", representation_type=self.representation_type, transform=self.inference_transform
#      57         )
#      58         self.datasets.extend([self.train, self.val])
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/training/data/datasets.py:151, in MimicDataset.__init__(self, split, representation_type, target, bp_targets, transform)
#     149 self.target = target
#     150 self.bp_targets = bp_targets
# --> 151 super().__init__(split, representation_type, transform)
#     152 bp_targets_idxs = {"sbp": 0, "dbp": 1}
#     153 bp_targets_idxs = [bp_targets_idxs[target] for target in bp_targets]
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/training/data/datasets.py:28, in BaseDataset.__init__(self, split, representation_type, transform)
#      26 self.representation_type = representation_type
#      27 self.transform = transform
# ---> 28 dataset = self._dataset_loader(split=split, representation_type=representation_type)
#      29 self.data = dataset["data"].float()
#      30 self.data = torch.nan_to_num(self.data)  # TODO
#
# File ~/Desktop/praca_magisterska/medical_signal_representation/msr/data/dataset_providers.py:136, in DatasetProvider.load_split(self, split, representation_type)
#     134 def load_split(self, split, representation_type):
#     135     representation_path = self.representations_path / representation_type
# --> 136     data = torch.load(representation_path / f"{split}.pt")
#     137     targets = torch.load(self.targets_path / f"{split}.pt")
#     138     try:
#
# File ~/.cache/pypoetry/virtualenvs/msr-xbuxOujG-py3.8/lib/python3.8/site-packages/torch/serialization.py:771, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     768 if 'encoding' not in pickle_load_args.keys():
#     769     pickle_load_args['encoding'] = 'utf-8'
# --> 771 with _open_file_like(f, 'rb') as opened_file:
#     772     if _is_zipfile(opened_file):
#     773         # The zipfile reader is going to advance the current file position.
#     774         # If we want to actually tail call to torch.jit.load, we need to
#     775         # reset back to the original position.
#     776         orig_position = opened_file.tell()
#
# File ~/.cache/pypoetry/virtualenvs/msr-xbuxOujG-py3.8/lib/python3.8/site-packages/torch/serialization.py:270, in _open_file_like(name_or_buffer, mode)
#     268 def _open_file_like(name_or_buffer, mode):
#     269     if _is_path(name_or_buffer):
# --> 270         return _open_file(name_or_buffer, mode)
#     271     else:
#     272         if 'w' in mode:
#
# File ~/.cache/pypoetry/virtualenvs/msr-xbuxOujG-py3.8/lib/python3.8/site-packages/torch/serialization.py:251, in _open_file.__init__(self, name, mode)
#     250 def __init__(self, name, mode):
# --> 251     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/shate/Desktop/praca_magisterska/medical_signal_representation/data/mimic/representations/beats_waveforms/train.pt'

# %% [markdown]
# **`beats_features`**

# %%
dm = MimicDataModule("beats_features")
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# No info file for that split
# No info file for that split
# No info file for that split
# MimicDataModule (beats_features)
#
#   Train MimicDataset:
#     data_shape            = torch.Size([14559, 120, 66])
#
#   Val MimicDataset:
#     data_shape            = torch.Size([3130, 120, 66])
#
#   Test MimicDataset:
#     data_shape            = torch.Size([3153, 120, 66])

# %% [markdown]
# ---
# # **Aggregated beat**

# %% [markdown]
# **`agg_beat_waveforms`**

# %%
dm = MimicDataModule("agg_beat_waveforms")
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# No info file for that split
# No info file for that split
# No info file for that split
# MimicDataModule (agg_beat_waveforms)
#
#   Train MimicDataset:
#     data_shape            = torch.Size([14559, 100, 2])
#
#   Val MimicDataset:
#     data_shape            = torch.Size([3130, 100, 2])
#
#   Test MimicDataset:
#     data_shape            = torch.Size([3153, 100, 2])

# %% [markdown]
# **`agg_beat_features`**

# %%
dm = MimicDataModule("agg_beat_features", bp_targets=["sbp"])
dm.setup(); print(dm.describe(ds_fields=['data_shape'], dm_fields=[]))
# Out:
# No info file for that split
# No info file for that split
# No info file for that split
# MimicDataModule (agg_beat_features)
#
#   Train MimicDataset:
#     data_shape            = torch.Size([14559, 122])
#
#   Val MimicDataset:
#     data_shape            = torch.Size([3130, 122])
#
#   Test MimicDataset:
#     data_shape            = torch.Size([3153, 122])

# %% [markdown]
# ---
